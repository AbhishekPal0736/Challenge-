# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekPal0736/Challenge-/blob/main/car_missing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as pt

# %%
df=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Car%20Sales%20Missing%20Data.csv')
df
# Out:
#        Make Colour  Odometer (KM)  Doors      Price
# 0    Nissan  Black        10148.0    4.0  Rs1366850
# 1    Toyota  White        10217.0    4.0  Rs1144150
# 2    Toyota  White        10247.0    4.0  Rs1628300
# 3     Honda  White        10953.0    4.0   Rs831800
# 4    Nissan   Blue        10954.0    4.0  Rs1521950
# ..      ...    ...            ...    ...        ...
# 995  Toyota  White            NaN    4.0  Rs1706650
# 996  Toyota  White            NaN    4.0  Rs1767900
# 997     BMW  White            NaN    5.0  Rs1906400
# 998  Toyota  White            NaN    4.0        NaN
# 999  Toyota  White            NaN    4.0        NaN
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
df.head(20)
# Out:
#       Make Colour  Odometer (KM)  Doors      Price
# 0   Nissan  Black        10148.0    4.0  Rs1366850
# 1   Toyota  White        10217.0    4.0  Rs1144150
# 2   Toyota  White        10247.0    4.0  Rs1628300
# 3    Honda  White        10953.0    4.0   Rs831800
# 4   Nissan   Blue        10954.0    4.0  Rs1521950
# 5    Honda    Red        11035.0    4.0   Rs530100
# 6      BMW  Black        11049.0    3.0   Rs975000
# 7    Honda  White        11119.0    4.0  Rs1042250
# 8   Toyota  White        12141.0    4.0   Rs877800
# 9   Toyota    Red        13050.0    4.0   Rs453700
# 10   Honda  White        13116.0    4.0   Rs823200
# 11     NaN  Black        13266.0    4.0   Rs725100
# 12  Toyota  White        14497.0    4.0   Rs991900
# 13  Toyota   Blue        14645.0    4.0  Rs1066300
# 14   Honda  White        14700.0    4.0  Rs1348650
# 15   Honda    Red        16079.0    4.0   Rs497700
# 16     BMW  White        16274.0    5.0  Rs2622900
# ...

# %%
df.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
sn.heatmap(df.isna())
pt.show()

# %%
df.fillna({'Colour':'nomne','Doors':2 })
# Out:
#        Make Colour  Odometer (KM)  Doors      Price
# 0    Nissan  Black        10148.0    4.0  Rs1366850
# 1    Toyota  White        10217.0    4.0  Rs1144150
# 2    Toyota  White        10247.0    4.0  Rs1628300
# 3     Honda  White        10953.0    4.0   Rs831800
# 4    Nissan   Blue        10954.0    4.0  Rs1521950
# ..      ...    ...            ...    ...        ...
# 995  Toyota  White            NaN    4.0  Rs1706650
# 996  Toyota  White            NaN    4.0  Rs1767900
# 997     BMW  White            NaN    5.0  Rs1906400
# 998  Toyota  White            NaN    4.0        NaN
# 999  Toyota  White            NaN    4.0        NaN
#
# [1000 rows x 5 columns]

# %%
df.fillna(method='ffill')
# Out:
#        Make Colour  Odometer (KM)  Doors      Price
# 0    Nissan  Black        10148.0    4.0  Rs1366850
# 1    Toyota  White        10217.0    4.0  Rs1144150
# 2    Toyota  White        10247.0    4.0  Rs1628300
# 3     Honda  White        10953.0    4.0   Rs831800
# 4    Nissan   Blue        10954.0    4.0  Rs1521950
# ..      ...    ...            ...    ...        ...
# 995  Toyota  White       249860.0    4.0  Rs1706650
# 996  Toyota  White       249860.0    4.0  Rs1767900
# 997     BMW  White       249860.0    5.0  Rs1906400
# 998  Toyota  White       249860.0    4.0  Rs1906400
# 999  Toyota  White       249860.0    4.0  Rs1906400
#
# [1000 rows x 5 columns]

# %%
df.interpolate(method='bfill')
# Out:
#        Make Colour  Odometer (KM)  Doors      Price
# 0    Nissan  Black        10148.0    4.0  Rs1366850
# 1    Toyota  White        10217.0    4.0  Rs1144150
# 2    Toyota  White        10247.0    4.0  Rs1628300
# 3     Honda  White        10953.0    4.0   Rs831800
# 4    Nissan   Blue        10954.0    4.0  Rs1521950
# ..      ...    ...            ...    ...        ...
# 995  Toyota  White            NaN    4.0  Rs1706650
# 996  Toyota  White            NaN    4.0  Rs1767900
# 997     BMW  White            NaN    5.0  Rs1906400
# 998  Toyota  White            NaN    4.0        NaN
# 999  Toyota  White            NaN    4.0        NaN
#
# [1000 rows x 5 columns]
